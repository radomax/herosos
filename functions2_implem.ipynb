# %% [markdown]
# <a href="https://colab.research.google.com/github/radomax/herosos/blob/main/functions2_implem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
GreeingsBot - .format
# Out:
#   File "<ipython-input-1-98f5c335183a>", line 1
#     GreeingsBot - .format
#                   ^
# SyntaxError: invalid syntax

# %%
def greet(name):
    print("Hello, ", name, ". You are welcome!")

# %%
greet("Rado")
# Out:
# Hello Rado. You are welcome!

# %%
#see the space after dot...  ...not here?  Just in jupiter? (compare)

# %%
def greet(name):
    print("Hello {}. You are welcome!".format(name))

# %%
greet("Rado")
# Out:
# Hello Rado. You are welcome!

# %%
def greet(name, name2, name3):
    print("Hello {}, {}, {}. You are welcome!".format(name, name2, name3))

# %%
greet("Rado","Breal","Jacob")
# Out:
# Hello Rado, Breal, Jacob. You are welcome!
